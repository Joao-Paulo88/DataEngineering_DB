-- %%
%py

import sys, os
sys.path.append(os.path.abspath('/Workspace/vendas_pecas_etl/utils'))
from defs import *

-- %%
%py

mover_arquivos('/Volumes/vendas_pecas/default/my/processar/', '/Volumes/vendas_pecas/default/my/processados/')
