# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import *
from pyspark.sql.types import *
from pyspark.sql.functions import input_file_name

df = spark.df_vendas = spark.read.option("header", "true").csv("/Volumes/vendas_pecas/default/my/processar/vendas_pecas_automotiva.csv").limit(500)

# %%
df.coalesce(1).write.format('csv').option("header", "true").mode('append').save("/Volumes/vendas_pecas/default/my/processar/vendas_pecas_automotiva_parte4.csv")

# %%
display(df)
